# %%
from PyPDF2 import PdfReader
from googletrans import Translator
import re
import nltk

nltk.download('punkt')
from nltk.tokenize import word_tokenize, sent_tokenize
from collections import Counter
import string
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('portuguese'))
translator = Translator(service_urls=['translate.googleapis.com'])
# Out:
# [nltk_data] Downloading package punkt to /home/eduardo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/eduardo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import spacy
from spacy.lang.pt.examples import sentences

nlp = spacy.load("pt_core_news_sm")

# %%
import requests


def translate_long_text(text, dest='en', chunk_size=4500):
    """
    Translates text using Google Translate API directly
    """
    translated = []

    for start in range(0, len(text), chunk_size):
        piece = text[start:start + chunk_size]

        url = "https://translate.googleapis.com/translate_a/single"
        params = {
            "client": "gtx",
            "sl": "auto",
            "tl": dest,
            "dt": "t",
            "q": piece
        }

        response = requests.get(url, params=params)
        if response.status_code == 200:
            translations = response.json()[0]
            translated_piece = ''.join([t[0] for t in translations if t[0]])
            translated.append(translated_piece)

    return ' '.join(translated)

# %%
def clean_text(text):
    '''
    Remove: references style[1], \n
    :param text:
    :return:
    '''
    pattern = r'\d*https?://\S+|[\w.+-]+@[\w-]+\.[\w.-]+'
    text = text.replace("\u200b", "")
    text = text.replace('- ', '')
    text = text.replace(' -', '')
    text = text.replace('\n', '')
    text = re.sub(r'([A-Za-z])-\s+([A-Za-z])', r'\1\2', text)
    text = re.sub(r'\[[^\]]+\]', '', text)
    text = re.sub(r'\d*https?://\S+', '', text)
    text = re.sub(r'https?://\S+', '', text)
    text = re.sub(pattern, '', text)
    text = re.sub(r'(?:REFER[EÊ]NCIAS?|REFERENCES).*$', '', text, flags=re.DOTALL).strip()
    # text = re.sub(r'\d+', '', text)
    return text

# %%
import os
import pickle


def process_pdfs(input_dir: str, out_dir: str):
    for fname in os.listdir(input_dir):
        if not fname.lower().endswith(".pdf"):
            continue

        path = os.path.join(input_dir, fname)
        print(f"Processing: {path}")

        name = path.split('/')[-1].replace('.pdf', '')

        reader = PdfReader(path)
        full_text = []
        for page in reader.pages:
            full_text.append(page.extract_text())

        full_text = ' '.join(full_text)

        full_text = clean_text(full_text)

        # full_text = translate_long_text(full_text, dest='pt')
        # #
        # full_text = clean_text(full_text)

        with open(f"{out_dir}/{name}.pkl", "wb") as f:
            pickle.dump(full_text, f)

# %%
path_in = '../articles/original/portuguese'
path_out = '../articles/processed'
process_pdfs(path_in, path_out)
# Out:
# Processing: ../articles/original/portuguese/985-24772-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24774-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24763-2-10-20241004.pdf
# Processing: ../articles/original/portuguese/985-24749-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24773-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24757-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24775-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24753-2-10-20241004.pdf
# Processing: ../articles/original/portuguese/985-24761-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24748-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24770-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24771-2-10-20240925.pdf
# Processing: ../articles/original/portuguese/985-24743-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24742-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24744-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24760-1-10-20240923.pdf
# Processing: ../articles/original/portuguese/985-24765-1-10-20240923.pdf

# %%
with open(f"{path_out}/985-24760-1-10-20240923.pkl", "rb") as f:
    full_text = pickle.load(f)
full_text

full_text = re.sub(r'REFERÊNCIAS?.*$', '', full_text, flags=re.DOTALL).strip()
full_text
# Out:
# 'Jogos Digitais Sérios usados para o Exercício de Habilidades doPensamento Computacional em Criançascom Transtorno do Espectro AutistaKatherin Felipa Carhuaz MalpartidaInstituto de Ciências Matemáticas e de ComputaçãoUniversidade de São Paulo (USP)São Carlos, São Paulo,  Rios da Hora RodriguesInstituto de Ciências Matemáticas e de ComputaçãoUniversidade de São Paulo (USP)São Carlos, São Paulo,  Thinking (CT) is a reasoning process focused onsolving problems, promoting the development of cognitive skills. Se-rious games can contribute to exercise these skills, as they are play-ful and adaptable tools for different audiences. This paper presentsthe design and evaluation of a medium-fidelity serious digital gameprototype designed to help improve the cognitive skills of childrenwith Autism Spectrum Disorder (ASD), based on the fundamentalprinciples of PC. The first phase of the game design was completedand evaluated by Special Education professionals from a partnerinstitution. The observations and feedback collected are being dis-cussed with the development and research teams to implement thefunctional version of the game.KEYWORDSPensamento Computacional, Jogos Digitais Sérios, Transtorno doEspectro Autista.1 INTRODUÇÃOO Pensamento Computacional (PC) é descrito como uma abordagempara a resolução de problemas que integra o pensamento lógico comos fundamentos da Ciência da Computação. A cientista JeannetteWing destaca que o PC é uma competência que deveria ser desen-volvida por todos, não se restringindo apenas aos profissionais daárea de tecnologia .A crescente valorização do PC na educação básica é evidente empaíses como Inglaterra e Estados Unidos, que já implementaramestratégias para incorporar esses conhecimentos nos currículosescolares . No Brasil, a Sociedade Brasileira de Computação(SBC) apoia o ensino de Computação nas escolas, argumentando queo mesmo fornece compreensão sobre o mundo digital e ferramentaspara resolver problemas complexos .Considerando o contexto da educação inclusiva, é fundamentalque todos os estudantes, inclusive aqueles com deficiências ounecessidades educacionais específicas, tenham acesso ao ensinodo PC. O paradigma inclusivo promove abordagens coletivas querespeitam as diferenças individuais, criando ambientes propíciospara a aprendizagem inclusiva, especialmente para pessoas comDeficiência Intelectual (DI), que apresentam habilidades limitadasIn: Proceedings of the Brazilian Symposium on Multimedia and the Web (WebMe-dia’2024). Juiz de Fora, Brazil. Porto Alegre: Brazilian Computer Society, 2024.©2024 SBC – Brazilian Computing Society.ISSN 2966-2753em atenção, memorização, compreensão de conceitos, generalizaçãoe abstração .Crianças com DI podem se beneficiar do PC ao estimular e exerci-tar novas habilidades intelectuais por meio de métodos e ferramen-tas apropriadas. Os Jogos Digitais Sérios são recursos eficazes nessecontexto, uma vez que facilitam a aquisição do PC e promovem oexercício de funções cognitivas por meio de experiências lúdicas.Este artigo descreve o processo de design e avaliação de um JogoDigital Sério (JDS) experimental, que visa ser usado para exercitarhabilidades de compreensão, generalização e abstração em criançascom Transtorno do Espectro Autista (TEA), utilizando os princípiosdo PC. O jogo experimental foi analisado e avaliado por duas profis-sionais da Educação Especial de uma instituição parceira que assistecrianças e adolescentes com deficiência intelectual. As atividadesrelacionadas a este trabalho resultaram na criação de uma novamecânica de jogo sério que será disponibilizada em uma plataformade autoria de jogos RUFUS1, desenvolvida pelo grupo de pesquisadestes autores, permitindo a criação de jogos personalizados paradiferentes contextos e públicos alvo.Para o design do jogo, foi adotada uma abordagem de pesquisadoresbrasileiros, denominada SemTh , que visa a coprodução de jo-gos digitais em conjunto com partes interessadas. O design tambémconsiderou diretrizes de ace ...

# %%
with open(f"{path_out}/985-24763-2-10-20241004.pkl", "rb") as f:
    full_text = pickle.load(f)
full_text

full_text = re.sub(r'(?:REFER[EÊ]NCIAS?|REFERENCES).*$', '', full_text, flags=re.DOTALL).strip()
full_text
# Out:
# 'O Impacto de Estratégias de Embeddings de Grafos naExplicabilidade de Sistemas de RecomendaçãoAndré Levi  de São PauloSão Carlos, São Paulo, BrasilLeonardo  Federal de São Joãodel-ReiSão João del Rei, Minas Gerais, BrasilMarcelo Garcia  de São PauloSão Carlos, São Paulo, BrasilABSTRACTExplanations in recommender systems are essential in improvingtrust, transparency, and persuasion. Recently, using KnowledgeGraphs (KG) to generate explanations gained attention due to thesemantic representation of information in which items and their at-tributes are represented as nodes, connected by edges, representingconnections among them. Model-agnostic KG explainable algo-rithms can be based on syntactic approaches or graph embeddings.The impact of graph embedding strategies in generating meaning-ful explanations still needs to be studied in the literature. To fill thisgap, in this work, we evaluate the quality of explanations providedby different graph embeddings and compare them with traditionalsyntactic strategies. The quality of explanations was assessed usingthree metrics from the literature: diversity, popularity and recency.Results indicate that the embedding algorithm chosen impacts thequality of explanations and generates more balanced results regar-ding popularity and explanation diversity compared to syntacticapproaches.KEYWORDSSistemas de Recomendação, Explicações, Embedding de Grafos1 INTRODUÇÃOSistemas de Recomendação (SsR) são algoritmos que oferecem su-gestões a usuários não apenas com base em seus históricos de inte-rações, mas também em interações de outros usuários, metadadosde itens, conhecimento de domínio e informações contextuais .Para usufruir de todos essas informações, as arquiteturas de SsRvêm se apresentando cada vez mais complexas e, consequentemente,pouco transparentes quanto às explicações das recomendações re-alizadas aos usuários, tornando-se verdadeiras caixas pretas .No entanto, gerar explicações para recomendações têm recebidouma significativa atenção da literatura , pois podem melhoraros SsR ao fornecer transparência, confiança, eficácia, persuasão, esatisfação .Atualmente, as estratégias para geração de explicações para SsRpodem ser categorizadas, basicamente, em duas abordagens: 1)intrínsecas ao modelo; e 2) agnósticas ao modelo, chamadas depós-hoc . Modelos intrínsecos buscam gerar explicaçõesem conjunto com a recomendação em si, apresentando os motivosIn: Proceedings of the Brazilian Symposium on Multimedia and the Web (WebMe-dia’2024). Juiz de Fora, Brazil. 2024.©2024 SBC – Sociedade Brasileira de Computação.ISSN 2966-2753pelos quais um item interagido está relacionado com o recomen-dado . Métodos agnósticos ou pós-hoc, por outro lado, utilizamum algoritmo desassociado da recomendação para relacionar itensinteragidos com itens recomendados e, portanto, não dependem doalgoritmo de recomendação . Métodos agnósticos, geralmente,são enriquecidos por fontes externas, como Grafos de Conheci-mento (GCs), em que nós representam itens e atributos relacionadosa estes e arestas representam as relações semânticas entre os nós, sendo esse o foco do presente trabalho.Os atuais algoritmos GC pós-hoc predominantemente utilizamabordagens sintáticas em que a relevância dos caminhos que co-nectam itens interagidos e recomendados é medida por meio donúmero de links associados. No entanto, esta medida pode nãocapturar completamente as relações semânticas entre os dados. Emcontrapartida, abordagens baseadas em embedding de grafos podem gerar representações semânticas de caminhos entre nós deitens recomendados e interagidos ao projetá-los em um espaço ve-torial. Apesar do potencial impacto que a escolha do algoritmo deembedding de grafo utilizado pode ter na qualidade das explicaçõesdas recomendações realizadas , não encontramos na literaturatrabalhos que realizam essa avaliação.Assim, o objetivo principal desse artigo visa preencher essa la-cuna da literatura e comparar o impacto de diferentes algoritmos deembedding de  ...

# %%
# # Testing
# text = reader_ingles.pages[0].extract_text()
# text = clean_text(text)
# text = translate_long_text(text, dest='pt')
# text = clean_text(text)

# %%
def list_pickle_files(folder: str) -> list:
    pickles = []
    for fname in os.listdir(folder):
        if fname.lower().endswith(('.pkl', '.pickle')):
            pickles.append(os.path.join(folder, fname))
    return pickles


# Example usage:
folder_path = "../articles/processed"
files = list_pickle_files(folder_path)

# %%
def extract_abstract(text: str) -> str:
    """
    Return the substring of `text` before the section heading INTRODUÇÃO.
    Matches INTRODUÇÃO (with or without cedilla, case‑insensitive).
    """
    # look for INTRODUÇÃO (or INTRODUCAO) as a whole word
    m = re.search(r'\bINTRODU[CÇ]ÃO\b', text, flags=re.IGNORECASE)
    if m:
        # take everything before that match
        return text[:m.start()].strip()
    else:
        # fallback: no heading found, return entire text
        return text.strip()

# %% [markdown]
# - Numero de sentenças
#
# - Numero medio de sentenças
#
# - Numero de tokens
#
# - Numero medio de tokens
#
#  - Top-10 tokens
#
# - Down-10 tokens
#
# - Numero de substativos
#
# - Numero de verbos
#
# - Numero de preposições

# %%
def top_n_tokens(text: str, n: int = 10):
    # 1) tokenize and lowercase
    tokens = word_tokenize(text, language='portuguese')
    tokens = [t.lower() for t in tokens]
    tokens = [
        t for t in tokens
        if t.isalpha()
           and t not in stop_words
    ]
    counts = Counter(tokens)
    least = sorted(counts.items(), key=lambda x: x[1])
    return Counter(tokens).most_common(n), least[:n]

# %%
def count_pos_tag(text: str):
    '''
    Count the number of nouns, verbs and prepositions in a text.
    :param text:
    :return:
    '''
    doc = nlp(text)
    counts = {'nouns': 0, 'verbs': 0, 'prepositions': 0}

    for tok in doc:
        if tok.pos_ in ('NOUN', 'PROPN'):  # common & proper nouns
            counts['nouns'] += 1
        elif tok.pos_ == 'VERB':  # verbs
            counts['verbs'] += 1
        elif tok.pos_ == 'ADP':  # adpositions
            counts['prepositions'] += 1

    return counts

# %%
total_sentences = 0
total_tokens = 0

for paper in files:
    with open(paper, "rb") as f:
        text = pickle.load(f)
    print('*' * 100)
    print('Artigo:', paper)
    print('*' * 100)
    tokens = word_tokenize(text)
    sentences = sent_tokenize(text, language='portuguese')
    total_sentences += len(sentences)
    total_tokens += len(tokens)
    print(f"Tokens: {len(tokens)}")
    print('*' * 100)
    print(f"Sentences: {len(sentences)}")
    print('*' * 100)
    top, down = top_n_tokens(text, 10)
    print('Top-10 tokens:', top)
    print('*' * 100)
    print('Down-10 tokens:', down)
    print('*' * 100)
    print('Qtd Substantivos:', count_pos_tag(text)['nouns'], )
    print('Qtd Verbos:', count_pos_tag(text)['verbs'])
    print('Qtd Preposições:', count_pos_tag(text)['prepositions'])

print('*' * 100)
print('*' * 100)
print('Número Médio de Tokens:', total_tokens / len(files))
print('Número Médio de Sentenças:', total_sentences / len(files))
# Out:
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24753-2-10-20241004.pkl
# ****************************************************************************************************
# Tokens: 9050
# ****************************************************************************************************
# Sentences: 160
# ****************************************************************************************************
# Top-10 tokens: [('undersampling', 49), ('métodos', 49), ('classe', 47), ('dados', 36), ('viés', 35), ('instâncias', 33), ('modelos', 28), ('transformers', 27), ('efetividade', 25), ('classificação', 25)]
# ****************************************************************************************************
# Down-10 tokens: [('emclassificação', 1), ('transformersguilherme', 1), ('brazilgabriel', 1), ('brazilwashington', 1), ('brazilmarcos', 1), ('brazilleonardo', 1), ('brazilabstractautomatic', 1), ('text', 1), ('classification', 1), ('unbalanced', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2299
# Qtd Verbos: 629
# Qtd Preposições: 1007
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24776-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 9931
# ****************************************************************************************************
# Sentences: 484
# ****************************************************************************************************
# Top-10 tokens: [('itens', 69), ('dados', 47), ('recomendação', 43), ('sistemas', 41), ('avaliação', 40), ('resultados', 35), ('conteúdo', 31), ('sobre', 31), ('incorporação', 29), ('modelos', 28)]
# ****************************************************************************************************
# Down-10 tokens: [('carlossão', 1), ('carlos', 1), ('spbruno', 1), ('pactualsão', 1), ('paulo', 1), ('sptiago', 1), ('carlossorocaba', 1), ('spabstractwith', 1), ('constante', 1), ('leva', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 3520
# Qtd Verbos: 755
# Qtd Preposições: 1454
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24745-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 6316
# ****************************************************************************************************
# Sentences: 311
# ****************************************************************************************************
# Top-10 tokens: [('sinais', 44), ('dados', 44), ('reconhecimento', 34), ('precisão', 29), ('modelo', 28), ('and', 25), ('the', 25), ('et', 24), ('tempo', 22), ('al', 22)]
# ****************************************************************************************************
# Down-10 tokens: [('automatic', 1), ('languagebased', 1), ('warpinglucas', 1), ('geraislucas', 1), ('geraissilvio', 1), ('jamil', 1), ('geraiszenilton', 1), ('patrocínio', 1), ('geraisleonardo', 1), ('vilela', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2463
# Qtd Verbos: 491
# Qtd Preposições: 780
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24763-2-10-20241004.pkl
# ****************************************************************************************************
# Tokens: 6944
# ****************************************************************************************************
# Sentences: 145
# ****************************************************************************************************
# Top-10 tokens: [('itens', 59), ('algoritmos', 47), ('explicação', 41), ('explicações', 40), ('atributos', 39), ('gc', 35), ('embeddings', 33), ('métricas', 32), ('grafos', 29), ('embedding', 26)]
# ****************************************************************************************************
# Down-10 tokens: [('naexplicabilidade', 1), ('recomendaçãoandré', 1), ('brasilleonardo', 1), ('federal', 1), ('joão', 1), ('del', 1), ('rei', 1), ('minas', 1), ('gerais', 1), ('brasilmarcelo', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2195
# Qtd Verbos: 643
# Qtd Preposições: 1089
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24761-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 6247
# ****************************************************************************************************
# Sentences: 137
# ****************************************************************************************************
# Top-10 tokens: [('vídeo', 51), ('quadros', 48), ('middleware', 43), ('aplicações', 33), ('sistema', 27), ('borda', 21), ('processamento', 21), ('transmissão', 19), ('latência', 19), ('distribuição', 18)]
# ****************************************************************************************************
# Down-10 tokens: [('àcomputação', 1), ('brasilrafael', 1), ('brasilalysson', 1), ('brasilruan', 1), ('d', 1), ('brasilabstractwithin', 1), ('scope', 1), ('extensivelyemployed', 1), ('monitoring', 1), ('control', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2161
# Qtd Verbos: 633
# Qtd Preposições: 1098
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24771-2-10-20240925.pkl
# ****************************************************************************************************
# Tokens: 7515
# ****************************************************************************************************
# Sentences: 163
# ****************************************************************************************************
# Top-10 tokens: [('arestas', 74), ('disseminação', 54), ('volume', 47), ('redes', 45), ('tempo', 41), ('usuários', 37), ('classe', 35), ('rede', 32), ('número', 30), ('forma', 28)]
# ****************************************************************************************************
# Down-10 tokens: [('sociaisgeovana', 1), ('otávio', 1), ('vinícius', 1), ('jussara', 1), ('ronan', 1), ('carlos', 1), ('sistemas', 1), ('ciências', 1), ('exatas', 1), ('minas', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2379
# Qtd Verbos: 666
# Qtd Preposições: 1215
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24754-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 7305
# ****************************************************************************************************
# Sentences: 305
# ****************************************************************************************************
# Top-10 tokens: [('interface', 48), ('ncl', 41), ('comando', 36), ('código', 34), ('visual', 33), ('maior', 33), ('multimodal', 31), ('parte', 29), ('the', 27), ('participantes', 26)]
# ****************************************************************************************************
# Down-10 tokens: [('exploring', 1), ('interaction', 1), ('authoringpaulo', 1), ('borgespontifical', 1), ('moraespontifical', 1), ('labfluminense', 1), ('universitynitéroi', 1), ('colcherpontifical', 1), ('inovadoras', 1), ('i', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2536
# Qtd Verbos: 702
# Qtd Preposições: 997
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24770-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 5084
# ****************************************************************************************************
# Sentences: 111
# ****************************************************************************************************
# Top-10 tokens: [('bsn', 27), ('usuário', 24), ('dados', 23), ('acelerômetro', 17), ('rotação', 16), ('dispositivo', 15), ('framework', 14), ('corporal', 14), ('perna', 14), ('corpo', 13)]
# ****************************************************************************************************
# Down-10 tokens: [('multimídiaelvis', 1), ('brasilalexandre', 1), ('pontifícia', 1), ('católica', 1), ('decampinas', 1), ('campinas', 1), ('brasilmarcelo', 1), ('paulo', 1), ('unifesp', 1), ('osasco', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 1678
# Qtd Verbos: 565
# Qtd Preposições: 748
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24739-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 5657
# ****************************************************************************************************
# Sentences: 223
# ****************************************************************************************************
# Top-10 tokens: [('codificação', 49), ('vídeo', 43), ('uso', 33), ('pontos', 25), ('tempo', 23), ('resultados', 22), ('complexidade', 22), ('hevc', 21), ('geometria', 20), ('figura', 19)]
# ****************************************************************************************************
# Down-10 tokens: [('gustavo', 1), ('brazileduardo', 1), ('brazilguilherme', 1), ('brazilcristiano', 1), ('brazilmarcelo', 1), ('brazilabstractin', 1), ('recent', 1), ('years', 1), ('content', 1), ('has', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 3983
# Qtd Verbos: 381
# Qtd Preposições: 967
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24751-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 6761
# ****************************************************************************************************
# Sentences: 280
# ****************************************************************************************************
# Top-10 tokens: [('the', 51), ('queda', 40), ('sensores', 30), ('quedas', 24), ('and', 24), ('idosos', 23), ('pessoa', 22), ('of', 22), ('to', 21), ('dados', 20)]
# ****************************************************************************************************
# Down-10 tokens: [('júlia', 1), ('lavrasbrazilandré', 1), ('ciências', 1), ('lavrasbrazilanonrom', 1), ('lavrasbrazilabstract', 1), ('progresso', 1), ('traz', 1), ('numerosos', 1), ('quais', 1), ('aumento', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2541
# Qtd Verbos: 631
# Qtd Preposições: 898
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24744-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 6742
# ****************************************************************************************************
# Sentences: 120
# ****************************************************************************************************
# Top-10 tokens: [('dados', 99), ('arquitetura', 42), ('saúde', 37), ('névoa', 35), ('rede', 34), ('nuvem', 31), ('latência', 30), ('computação', 28), ('tempo', 24), ('ambientes', 23)]
# ****************************************************************************************************
# Down-10 tokens: [('cloudcomputingjuan', 1), ('felipe', 1), ('souza', 1), ('oliveirainstituto', 1), ('cesar', 1), ('salgado', 1), ('vidalinstituto', 1), ('moreira', 1), ('sallesciicesi', 1), ('estg', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2504
# Qtd Verbos: 657
# Qtd Preposições: 1150
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24740-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 8053
# ****************************************************************************************************
# Sentences: 350
# ****************************************************************************************************
# Top-10 tokens: [('estudo', 73), ('sistemas', 52), ('sistema', 52), ('usabilidade', 48), ('problemas', 46), ('radiologia', 42), ('imagens', 41), ('the', 37), ('of', 35), ('software', 35)]
# ****************************************************************************************************
# Down-10 tokens: [('completo', 1), ('radiologiafábio', 1), ('cândido', 1), ('brasilandré', 1), ('brasilmarluce', 1), ('brasilabstractthe', 1), ('increasing', 1), ('demand', 1), ('tests', 1), ('has', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 3062
# Qtd Verbos: 675
# Qtd Preposições: 1170
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24749-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 5775
# ****************************************************************************************************
# Sentences: 145
# ****************************************************************************************************
# Top-10 tokens: [('hábitos', 41), ('pacientes', 36), ('fatores', 34), ('risco', 32), ('modelo', 31), ('comportamentos', 28), ('usuário', 27), ('análise', 26), ('comportamento', 24), ('dados', 21)]
# ****************************************************************************************************
# Down-10 tokens: [('humanolucas', 1), ('pfeiffer', 1), ('salomão', 1), ('rsjorge', 1), ('luis', 1), ('victória', 1), ('rsabstractchronic', 1), ('among', 1), ('out', 1), ('leading', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2150
# Qtd Verbos: 552
# Qtd Preposições: 794
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24775-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 5460
# ****************************************************************************************************
# Sentences: 138
# ****************************************************************************************************
# Top-10 tokens: [('emocionais', 44), ('indivíduos', 44), ('dados', 30), ('usuários', 29), ('emoções', 23), ('respostas', 21), ('cada', 21), ('análise', 21), ('comparação', 20), ('abordagem', 19)]
# ****************************************************************************************************
# Down-10 tokens: [('indivíduosao', 1), ('audiovisualguilherme', 1), ('aguiarjuan', 1), ('estevesinstituto', 1), ('grossopontes', 1), ('lacerda', 1), ('pereira', 1), ('júniorthamer', 1), ('nascimentoinstituto', 1), ('goianoiporá', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 1707
# Qtd Verbos: 538
# Qtd Preposições: 864
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24759-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 8393
# ****************************************************************************************************
# Sentences: 490
# ****************************************************************************************************
# Top-10 tokens: [('dados', 54), ('estudos', 43), ('atenção', 40), ('pesquisa', 36), ('of', 33), ('and', 30), ('análise', 28), ('ieee', 28), ('al', 26), ('in', 25)]
# ****************************************************************************************************
# Down-10 tokens: [('ênfase', 1), ('datacassiano', 1), ('silva', 1), ('riograde', 1), ('sul', 1), ('institutos', 1), ('federais', 1), ('selbach', 1), ('brasilenos', 1), ('avermelhados', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 3266
# Qtd Verbos: 653
# Qtd Preposições: 1087
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24766-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 9358
# ****************************************************************************************************
# Sentences: 469
# ****************************************************************************************************
# Top-10 tokens: [('reconhecimento', 55), ('emoções', 49), ('facial', 49), ('dados', 46), ('face', 44), ('faciais', 40), ('expressão', 37), ('imagens', 36), ('coordenadas', 33), ('imagem', 32)]
# ****************************************************************************************************
# Down-10 tokens: [('alanidade', 1), ('usp', 1), ('dcm', 1), ('preto', 1), ('brazilleandro', 1), ('persofernando', 1), ('pauloo', 1), ('fflrp', 1), ('fflro', 1), ('brasilillendro', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 3286
# Qtd Verbos: 718
# Qtd Preposições: 1318
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24762-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 7582
# ****************************************************************************************************
# Sentences: 339
# ****************************************************************************************************
# Top-10 tokens: [('vídeo', 50), ('qualidade', 44), ('vídeos', 40), ('domínios', 31), ('dados', 29), ('modelo', 27), ('treinamento', 25), ('vários', 24), ('vv', 24), ('ieee', 23)]
# ****************************************************************************************************
# Down-10 tokens: [('enhancementgaribaldi', 1), ('brazilgilberto', 1), ('brazilbruno', 1), ('brazildaniel', 1), ('brazilguilherme', 1), ('brazilabstractlossy', 1), ('degradar', 1), ('mitigação', 1), ('deep', 1), ('poder', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2672
# Qtd Verbos: 556
# Qtd Preposições: 1153
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24767-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 6475
# ****************************************************************************************************
# Sentences: 301
# ****************************************************************************************************
# Top-10 tokens: [('taxonomias', 46), ('termos', 44), ('dados', 34), ('cada', 33), ('taxonomia', 30), ('tópicos', 24), ('tópico', 23), ('modelos', 22), ('llms', 21), ('conjunto', 19)]
# ****************************************************************************************************
# Down-10 tokens: [('morastelemín', 1), ('favarobtg', 1), ('cozinhapasaucepizizawinetransaction', 1), ('builseat', 1), ('pag', 1), ('ristorantemacrocategoryfoodmicrocaterestaurntweb', 1), ('scripperlmnana', 1), ('ristorantetehomestyle', 1), ('mastas', 1), ('comentas', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2248
# Qtd Verbos: 547
# Qtd Preposições: 931
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24747-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 8596
# ****************************************************************************************************
# Sentences: 392
# ****************************************************************************************************
# Top-10 tokens: [('entidades', 78), ('propriedades', 63), ('perguntas', 58), ('modelos', 55), ('sistema', 45), ('conhecimento', 43), ('precisão', 43), ('consultas', 40), ('base', 39), ('kbqa', 38)]
# ****************************************************************************************************
# Down-10 tokens: [('implementationrômulo', 1), ('computer', 1), ('federal', 1), ('mg', 1), ('jorão', 1), ('ecossistemas', 1), ('digitais', 1), ('macsvien', 1), ('economia', 1), ('business', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2941
# Qtd Verbos: 881
# Qtd Preposições: 1231
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24756-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 7957
# ****************************************************************************************************
# Sentences: 328
# ****************************************************************************************************
# Top-10 tokens: [('sites', 91), ('notícias', 80), ('the', 54), ('metodologia', 53), ('of', 52), ('falsas', 51), ('and', 36), ('site', 24), ('usuários', 23), ('in', 22)]
# ****************************************************************************************************
# Down-10 tokens: [('wildleandro', 1), ('araujouniversidade', 1), ('coutouniversidade', 1), ('neryuniversidade', 1), ('rodriguesuniversidade', 1), ('almeidauniversidade', 1), ('reisuniversidade', 1), ('viçosaviçosa', 1), ('benevenutouniversidade', 1), ('battle', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2840
# Qtd Verbos: 698
# Qtd Preposições: 1108
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24748-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 6726
# ****************************************************************************************************
# Sentences: 175
# ****************************************************************************************************
# Top-10 tokens: [('tiktok', 45), ('dados', 44), ('publicidade', 43), ('infantil', 34), ('vídeos', 34), ('crianças', 24), ('base', 23), ('influenciadores', 22), ('modelo', 22), ('modelos', 20)]
# ****************************************************************************************************
# Down-10 tokens: [('tiktokraíssa', 1), ('gonçalves', 1), ('lopes', 1), ('carvalhodepartamento', 1), ('torres', 1), ('study', 1), ('addresses', 1), ('identification', 1), ('tiktokand', 1), ('its', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2210
# Qtd Verbos: 813
# Qtd Preposições: 1004
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24741-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 6465
# ****************************************************************************************************
# Sentences: 287
# ****************************************************************************************************
# Top-10 tokens: [('dados', 45), ('desempenho', 45), ('detecção', 42), ('conjunto', 41), ('deepfake', 31), ('modelos', 24), ('conhecimento', 24), ('abordagem', 23), ('abordagens', 21), ('comitê', 21)]
# ****************************************************************************************************
# Down-10 tokens: [('feacesyan', 1), ('martins', 1), ('gurevitz', 1), ('janeirojosé', 1), ('matheus', 1), ('janeirodaniel', 1), ('sousa', 1), ('janeiropedro', 1), ('cutrim', 1), ('janeiropolyana', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2331
# Qtd Verbos: 510
# Qtd Preposições: 1006
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24750-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 8510
# ****************************************************************************************************
# Sentences: 375
# ****************************************************************************************************
# Top-10 tokens: [('entidades', 72), ('entidade', 66), ('literais', 50), ('dados', 49), ('vetores', 33), ('q', 33), ('representações', 31), ('the', 28), ('sobre', 26), ('kg', 26)]
# ****************************************************************************************************
# Down-10 tokens: [('approachítalo', 1), ('m', 1), ('minas', 1), ('gerais', 1), ('sjesão', 1), ('joão', 1), ('evangelista', 1), ('brasilanderson', 1), ('ouro', 1), ('pretoouro', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 3080
# Qtd Verbos: 709
# Qtd Preposições: 1157
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24769-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 8420
# ****************************************************************************************************
# Sentences: 380
# ****************************************************************************************************
# Top-10 tokens: [('usuários', 58), ('the', 51), ('tópicos', 40), ('análise', 36), ('of', 36), ('sobre', 35), ('eleições', 34), ('twitter', 33), ('and', 32), ('rede', 31)]
# ****************************************************************************************************
# Down-10 tokens: [('retrato', 1), ('geraisgiovana', 1), ('geraescarlos', 1), ('ouro', 1), ('pretoana', 1), ('geraisabstract', 1), ('gerações', 1), ('evidente', 1), ('formas', 1), ('platadas', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 3123
# Qtd Verbos: 588
# Qtd Preposições: 1110
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24774-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 6209
# ****************************************************************************************************
# Sentences: 178
# ****************************************************************************************************
# Top-10 tokens: [('módulo', 84), ('módulos', 56), ('framework', 42), ('pode', 37), ('eva', 33), ('robô', 33), ('controle', 32), ('sistema', 25), ('tópico', 20), ('software', 19)]
# ****************************************************************************************************
# Down-10 tokens: [('paraplataformas', 1), ('socialmarcelo', 1), ('rochamídiacom', 1), ('faveladepartment', 1), ('sciencecentro', 1), ('investigación', 1), ('científica', 1), ('yde', 1), ('educación', 1), ('superior', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2170
# Qtd Verbos: 712
# Qtd Preposições: 907
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24737-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 10860
# ****************************************************************************************************
# Sentences: 641
# ****************************************************************************************************
# Top-10 tokens: [('modelos', 55), ('dados', 54), ('aae', 51), ('expressões', 48), ('análise', 37), ('et', 26), ('ml', 25), ('sobre', 25), ('sentimentos', 24), ('conjuntos', 24)]
# ****************************************************************************************************
# Down-10 tokens: [('comprehensive', 1), ('view', 1), ('towards', 1), ('with', 1), ('african', 1), ('americanenglish', 1), ('expressionsguilherme', 1), ('andrade', 1), ('luiz', 1), ('nery', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 3595
# Qtd Verbos: 885
# Qtd Preposições: 1579
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24738-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 6556
# ****************************************************************************************************
# Sentences: 314
# ****************************************************************************************************
# Top-10 tokens: [('multimídia', 109), ('r', 40), ('sfc', 36), ('sfcs', 35), ('i', 35), ('l', 30), ('prisma', 29), ('multimedia', 28), ('vnf', 24), ('virtualização', 19)]
# ****************************************************************************************************
# Down-10 tokens: [('functioncains', 1), ('sensorsfranklin', 1), ('jordan', 1), ('brasilanselmo', 1), ('brasilertora', 1), ('federalnitrantrt', 1), ('heterogêneos', 1), ('internetof', 1), ('arean', 1), ('importante', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2396
# Qtd Verbos: 576
# Qtd Preposições: 823
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24752-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 10502
# ****************************************************************************************************
# Sentences: 490
# ****************************************************************************************************
# Top-10 tokens: [('reconhecimento', 73), ('widgets', 67), ('gui', 44), ('widget', 43), ('dados', 40), ('android', 37), ('one', 37), ('sobre', 34), ('teste', 33), ('testes', 31)]
# ****************************************************************************************************
# Down-10 tokens: [('enhancing', 1), ('testingusing', 1), ('vision', 1), ('techniquesyadini', 1), ('amlaís', 1), ('amgilmar', 1), ('amdaniel', 1), ('amleticia', 1), ('amjuan', 1), ('amrha', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 4047
# Qtd Verbos: 706
# Qtd Preposições: 1436
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24758-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 8352
# ****************************************************************************************************
# Sentences: 391
# ****************************************************************************************************
# Top-10 tokens: [('interoperabilidade', 103), ('guia', 90), ('teste', 85), ('iot', 84), ('testes', 49), ('internet', 34), ('sistemas', 32), ('avaliação', 24), ('características', 24), ('the', 24)]
# ****************************************************************************************************
# Down-10 tokens: [('thingskarina', 1), ('brancogrupo', 1), ('leitão', 1), ('dantascomputer', 1), ('departamento', 1), ('computação', 1), ('university', 1), ('expandiu', 1), ('integrantes', 1), ('intenso', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 3175
# Qtd Verbos: 638
# Qtd Preposições: 1222
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24760-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 823
# ****************************************************************************************************
# Sentences: 16
# ****************************************************************************************************
# Top-10 tokens: [('the', 10), ('pc', 10), ('jogos', 8), ('of', 7), ('and', 6), ('design', 6), ('digitais', 5), ('seção', 5), ('sérios', 4), ('paulo', 4)]
# ****************************************************************************************************
# Down-10 tokens: [('usados', 1), ('dopensamento', 1), ('autistakatherin', 1), ('malpartidainstituto', 1), ('rodriguesinstituto', 1), ('thinking', 1), ('ct', 1), ('is', 1), ('reasoning', 1), ('process', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 348
# Qtd Verbos: 77
# Qtd Preposições: 112
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24746-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 9528
# ****************************************************************************************************
# Sentences: 453
# ****************************************************************************************************
# Top-10 tokens: [('preferências', 64), ('gêneros', 60), ('gênero', 54), ('cluster', 51), ('the', 49), ('cidades', 41), ('música', 36), ('cada', 34), ('of', 33), ('and', 30)]
# ****************************************************************************************************
# Down-10 tokens: [('baseadas', 1), ('chartsfilipe', 1), ('ouro', 1), ('pretocarlos', 1), ('deco', 1), ('pretohelen', 1), ('mudou', 1), ('pessoas', 1), ('consomem', 1), ('enorme', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 3322
# Qtd Verbos: 664
# Qtd Preposições: 1217
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24772-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 5862
# ****************************************************************************************************
# Sentences: 140
# ****************************************************************************************************
# Top-10 tokens: [('itens', 53), ('popularidade', 50), ('usuário', 40), ('recomendações', 33), ('calibração', 32), ('dados', 27), ('usuários', 26), ('viés', 23), ('modelo', 23), ('abordagem', 22)]
# ****************************************************************************************************
# Down-10 tokens: [('doviés', 1), ('popularidaderodrigo', 1), ('souzauniversidade', 1), ('manzatouniversidade', 1), ('systems', 1), ('are', 1), ('designed', 1), ('personalizedsuggestions', 1), ('each', 1), ('enhance', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 1861
# Qtd Verbos: 657
# Qtd Preposições: 882
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24757-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 6006
# ****************************************************************************************************
# Sentences: 113
# ****************************************************************************************************
# Top-10 tokens: [('mensagens', 45), ('mental', 43), ('saúde', 42), ('termos', 42), ('pandemia', 35), ('usuários', 31), ('discord', 29), ('sobre', 24), ('uso', 23), ('período', 20)]
# ****************************************************************************************************
# Down-10 tokens: [('brasilpedro', 1), ('l', 1), ('meira', 1), ('period', 1), ('due', 1), ('generated', 1), ('asignificant', 1), ('impact', 1), ('our', 1), ('routines', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2018
# Qtd Verbos: 566
# Qtd Preposições: 882
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24742-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 7830
# ****************************************************************************************************
# Sentences: 184
# ****************************************************************************************************
# Top-10 tokens: [('comentários', 80), ('cigarro', 50), ('vídeos', 37), ('uso', 34), ('cigarros', 33), ('eletrônico', 32), ('modelo', 32), ('eletrônicos', 29), ('vape', 26), ('dados', 26)]
# ****************************************************************************************************
# Down-10 tokens: [('pormeio', 1), ('youtubealine', 1), ('richardy', 1), ('jussara', 1), ('helen', 1), ('carlos', 1), ('sistemas', 1), ('ouro', 1), ('minas', 1), ('gerais', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2619
# Qtd Verbos: 733
# Qtd Preposições: 1024
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24773-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 5999
# ****************************************************************************************************
# Sentences: 139
# ****************************************************************************************************
# Top-10 tokens: [('dados', 58), ('tradução', 52), ('sentenças', 47), ('substituição', 40), ('aumento', 32), ('palavras', 30), ('modelo', 30), ('sinônimos', 26), ('bleu', 24), ('retrotradução', 24)]
# ****************************************************************************************************
# Down-10 tokens: [('augmentationaplicadas', 1), ('andré', 1), ('aschoff', 1), ('limauniversidade', 1), ('ramon', 1), ('faustino', 1), ('souzauniversidade', 1), ('edson', 1), ('costauniversidade', 1), ('maritan', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2032
# Qtd Verbos: 570
# Qtd Preposições: 1007
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24755-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 8239
# ****************************************************************************************************
# Sentences: 309
# ****************************************************************************************************
# Top-10 tokens: [('isp', 123), ('modos', 89), ('codificação', 64), ('the', 60), ('modo', 55), ('angular', 49), ('intra', 40), ('decisão', 38), ('taxa', 38), ('mpm', 38)]
# ****************************************************************************************************
# Down-10 tokens: [('intraprediction', 1), ('learninglarissa', 1), ('araújovideo', 1), ('duartevideo', 1), ('grupo', 1), ('zattvideo', 1), ('programa', 1), ('pósgraduação', 1), ('incomputora', 1), ('ciência', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 3262
# Qtd Verbos: 597
# Qtd Preposições: 1179
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24764-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 6529
# ****************************************************************************************************
# Sentences: 345
# ****************************************************************************************************
# Top-10 tokens: [('medicamentos', 77), ('and', 56), ('ontologia', 47), ('of', 29), ('dados', 25), ('the', 25), ('saúde', 23), ('sistema', 22), ('ontodrug', 21), ('pode', 18)]
# ****************************************************************************************************
# Down-10 tokens: [('interoperabilitywith', 1), ('ontologynelson', 1), ('brazilmatheus', 1), ('brazildilvan', 1), ('brazilabstractthis', 1), ('artigo', 1), ('apresenta', 1), ('quadros', 1), ('padronizando', 1), ('identificando', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2574
# Qtd Verbos: 504
# Qtd Preposições: 776
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24765-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 6104
# ****************************************************************************************************
# Sentences: 164
# ****************************************************************************************************
# Top-10 tokens: [('jogos', 82), ('comentários', 56), ('review', 44), ('bombing', 34), ('metacritic', 27), ('jogo', 26), ('usuários', 25), ('the', 23), ('ataques', 21), ('toxicidade', 21)]
# ****************************************************************************************************
# Down-10 tokens: [('doreview', 1), ('metacriticmarcus', 1), ('vinicius', 1), ('geraisclara', 1), ('andrade', 1), ('horizonte', 1), ('geraisphilipe', 1), ('freitas', 1), ('geraisabstractthis', 1), ('investigates', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 1909
# Qtd Verbos: 674
# Qtd Preposições: 826
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24768-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 7359
# ****************************************************************************************************
# Sentences: 349
# ****************************************************************************************************
# Top-10 tokens: [('conteúdo', 60), ('tags', 59), ('instagram', 56), ('usuários', 51), ('texto', 41), ('dados', 38), ('postagens', 33), ('imagem', 28), ('análise', 25), ('imagens', 25)]
# ****************************************************************************************************
# Down-10 tokens: [('contentutilizando', 1), ('francisco', 1), ('hecksher', 1), ('viçosa', 1), ('ufvflorestal', 1), ('brasilphilipe', 1), ('freitas', 1), ('federal', 1), ('viçanda', 1), ('ufvfl', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2347
# Qtd Verbos: 622
# Qtd Preposições: 1053
# ****************************************************************************************************
# Artigo: ../articles/processed/985-24743-1-10-20240923.pkl
# ****************************************************************************************************
# Tokens: 7682
# ****************************************************************************************************
# Sentences: 154
# ****************************************************************************************************
# Top-10 tokens: [('comentários', 90), ('anotadores', 41), ('dizer', 38), ('sei', 36), ('sentimentos', 34), ('modelo', 34), ('agrupamento', 33), ('concordância', 31), ('análise', 28), ('dados', 28)]
# ****************************************************************************************************
# Down-10 tokens: [('emcomunidades', 1), ('humanosgiovana', 1), ('piorinouniversidade', 1), ('moreirauniversidade', 1), ('limauniversidade', 1), ('paganouniversidade', 1), ('silvauniversidade', 1), ('soaring', 1), ('use', 1), ('its', 1)]
# ****************************************************************************************************
# Qtd Substantivos: 2548
# Qtd Verbos: 784
# Qtd Preposições: 1097
# Número Médio de Tokens: 7244.05
# Número Médio de Sentenças: 274.7
